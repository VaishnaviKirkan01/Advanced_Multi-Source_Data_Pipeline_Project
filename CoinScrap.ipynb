# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
api_key="CG-asLe2FSYKNjGW7jkEFr2KPD1"

# %%
headers = {
    "CG-asLe2FSYKNjGW7jkEFr2KPD1":api_key
}

# %%
params={
    "vs_currency":"usd",
    "order":"market_cap_desc",
    'per_page':500,
    "page":1,
    "sparkline":False,
}

# %%
response=requests.get(
    url,
    headers=headers,
    params=params,
)

response.status_code
# Out:
# 200

# %%
#Getting the data

if response.status_code==200:
    data=response.json()

else:
    print("Something went wrong")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                     id symbol            name  \
# 0              bitcoin    btc         Bitcoin
# 1             ethereum    eth        Ethereum
# 2               tether   usdt          Tether
# 3          binancecoin    bnb             BNB
# 4               ripple    xrp             XRP
# ..                 ...    ...             ...
# 95  injective-protocol    inj       Injective
# 96      official-trump  trump  Official Trump
# 97              beldex    bdx          Beldex
# 98     xdce-crowd-sale    xdc     XDC Network
# 99            ether-fi  ethfi        Ether.fi
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   78634.000000
# 1   https://coin-images.coingecko.com/coins/images...    2483.720000
# 2   https://coin-images.coingecko.com/coins/images...       0.999612
# 3   https://coin-images.coingecko.com/coins/images...     757.330000
# 4   https://coin-images.coingecko.com/coins/images...       1.400000
# ..                                                ...            ...
# 95  https://coin-images.coingecko.com/coins/images...       6.250000
# 96  https://coin-images.coingecko.com/coins/images...       2.270000
# 97  https://coin-images.coingecko.com/coins/images...       0.077710
# 98  https://coin-images.coingecko.com/coins/images...       0.028983
# 99  https://coin-images.coingecko.com/coins/images...       0.592432
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0   1579089652770                1            1579090360482  2.838799e+10
# 1    303085220706                2             303085220706  1.078036e+10
# 2    183369701757                3             188834594823  5.236984e+10
# 3    100841624829                4             100841628010  1.107447e+09
# 4     87754936306                5             139840650751  1.896142e+09
# ..            ...              ...                      ...           ...
# 95      624512089               95                624512089  2.333809e+08
# 96      619265191               96               2267231895  1.876301e+08
# 97      611626584               97                772405069  1.099994e+07
# 98      578165056               98               1103353562  7.305587e+06
# 99      571926334               99                571926334  5.618779e+07
#
#         high_24h  ...  total_supply    max_supply            ath  \
# 0   79625.000000  ...  2.008138e+07  2.100000e+07  126080.000000
# 1    2510.030000  ...  1.220297e+08           NaN    4946.050000
# 2       0.999963  ...  1.889055e+11           NaN       1.320000
# 3     760.330000  ...  1.331615e+08  2.000000e+08    1369.990000
# 4       1.410000  ...  9.998563e+10  1.000000e+11       3.650000
# ..           ...  ...           ...           ...            ...
# 95      6.690000  ...  1.000000e+08           NaN      52.620000
# 96      2.330000  ...  1.000000e+09  1.000000e+09      73.430000
# 97      0.079171  ...  9.939509e+09           NaN       0.450785
# 98      0.029772  ...  3.806569e+10           NaN       0.192754
# 99      0.604093  ...  9.653500e+08  1.000000e+09       8.530000
#
#     ath_change_percentage                  ath_date        atl  \
# 0               -37.63171  2025-10-06T10:57:42.000Z  67.810000
# 1               -49.78373  2025-08-24T11:21:03.000Z   0.432979
# 2               -24.44896  2018-07-23T16:00:00.000Z   0.572521
# 3               -44.72041  2025-10-13T00:41:24.000Z   0.039818
# 4               -61.64502  2025-07-17T19:40:53.000Z   0.002686
# ..                    ...                       ...        ...
# 95              -88.13089  2024-03-14T07:06:22.000Z   0.657401
# 96              -96.91194  2025-01-19T03:50:34.000Z   1.370000
# 97              -82.76120  2018-12-16T16:00:00.000Z   0.000275
# 98              -84.96358  2021-08-20T20:39:48.000Z   0.000395
# 99              -93.05383  2024-03-27T15:14:46.000Z   0.266530
#
#     atl_change_percentage                  atl_date  \
# 0            1.158638e+05  2013-07-05T16:00:00.000Z
# 1            5.735357e+05  2015-10-19T16:00:00.000Z
# 2            7.459836e+01  2015-03-01T16:00:00.000Z
# 3            1.901883e+06  2017-10-18T16:00:00.000Z
# 4            5.196478e+04  2014-05-21T16:00:00.000Z
# ..                    ...                       ...
# 95           8.500454e+02  2020-11-03T08:19:30.000Z
# 96           6.548837e+01  2026-08-13T18:40:30.000Z
# 97           2.813909e+04  2019-11-01T03:05:12.000Z
# 98           7.231643e+03  2019-07-21T16:00:00.000Z
# 99           1.222760e+02  2026-06-05T19:19:15.000Z
#
#                                                   roi  \
# 0                                                None
# 1   {'times': 41.22744770600797, 'currency': 'btc'...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97  {'times': -0.6894284115450982, 'currency': 'us...
# 98  {'times': 0.5529974415539096, 'currency': 'eth...
# 99                                               None
#
#                 last_updated
# 0   2026-09-08T10:46:30.000Z
# 1   2026-09-08T10:46:30.000Z
# 2   2026-09-08T10:46:30.000Z
# 3   2026-09-08T10:46:30.000Z
# 4   2026-09-08T10:46:30.000Z
# ..                       ...
# 95  2026-09-08T10:46:30.000Z
# 96  2026-09-08T10:46:30.000Z
# 97  2026-09-08T10:46:30.000Z
# 98  2026-09-08T10:46:30.000Z
# 99  2026-09-08T10:46:30.000Z
#
# [100 rows x 26 columns]

# %%
df.to_csv("Scraped_crypto(1).csv")

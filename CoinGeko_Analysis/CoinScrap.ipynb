# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://api.coingecko.com/api/v3/coins/markets"
api_key="CG-asLe2FSYKNjGW7jkEFr2KPD1"

# %%
headers = {
    "CG-asLe2FSYKNjGW7jkEFr2KPD1":api_key
}

# %%
params={
    "vs_currency":"usd",
    "order":"market_cap_desc",
    'per_page':500,
    "page":1,
    "sparkline":False,
}

# %%
response=requests.get(
    url,
    headers=headers,
    params=params,
)

response.status_code
# Out:
# 200

# %%
#Getting the data

if response.status_code==200:
    data=response.json()

else:
    print("Something went wrong")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                     id symbol         name  \
# 0              bitcoin    btc      Bitcoin
# 1             ethereum    eth     Ethereum
# 2               tether   usdt       Tether
# 3          binancecoin    bnb          BNB
# 4               ripple    xrp          XRP
# ..                 ...    ...          ...
# 95              beldex    bdx       Beldex
# 96  injective-protocol    inj    Injective
# 97     xdce-crowd-sale    xdc  XDC Network
# 98      flare-networks    flr        Flare
# 99           usual-usd   usd0    Usual USD
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   76869.000000
# 1   https://coin-images.coingecko.com/coins/images...    2417.760000
# 2   https://coin-images.coingecko.com/coins/images...       0.999689
# 3   https://coin-images.coingecko.com/coins/images...     706.520000
# 4   https://coin-images.coingecko.com/coins/images...       1.360000
# ..                                                ...            ...
# 95  https://coin-images.coingecko.com/coins/images...       0.076862
# 96  https://coin-images.coingecko.com/coins/images...       5.930000
# 97  https://coin-images.coingecko.com/coins/images...       0.028112
# 98  https://coin-images.coingecko.com/coins/images...       0.006346
# 99  https://coin-images.coingecko.com/coins/images...       0.997173
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0   1543780270779                1            1543789572409  3.415245e+10
# 1    295019194043                2             295019194043  1.358600e+10
# 2    183399747382                3             188864872668  5.765036e+10
# 3     94081938222                4              94081937558  1.262140e+09
# 4     85090865143                5             135595357428  2.406497e+09
# ..            ...              ...                      ...           ...
# 95      604714731               96                763675850  1.169582e+07
# 96      593229023               97                593229023  8.349674e+07
# 97      560726767               98               1070074832  5.787636e+06
# 98      551497765               99                675979791  3.149003e+06
# 99      546890845              100                546890845  2.004420e+05
#
#         high_24h  ...  total_supply    max_supply            ath  \
# 0   79351.000000  ...  2.008236e+07  2.100000e+07  126080.000000
# 1    2513.050000  ...  1.220356e+08           NaN    4946.050000
# 2       0.999919  ...  1.889278e+11           NaN       1.320000
# 3     746.280000  ...  1.331612e+08  2.000000e+08    1369.990000
# 4       1.430000  ...  9.998563e+10  1.000000e+11       3.650000
# ..           ...  ...           ...           ...            ...
# 95      0.077063  ...  9.939535e+09           NaN       0.450785
# 96      6.250000  ...  1.000000e+08           NaN      52.620000
# 97      0.028855  ...  3.806569e+10           NaN       0.192754
# 98      0.006470  ...  1.065179e+11           NaN       0.150073
# 99      0.999036  ...  5.484531e+08           NaN       1.330000
#
#     ath_change_percentage                  ath_date        atl  \
# 0               -39.03115  2025-10-06T10:57:42.000Z  67.810000
# 1               -51.11726  2025-08-24T11:21:03.000Z   0.432979
# 2               -24.44314  2018-07-23T16:00:00.000Z   0.572521
# 3               -48.42904  2025-10-13T00:41:24.000Z   0.039818
# 4               -62.80759  2025-07-17T19:40:53.000Z   0.002686
# ..                    ...                       ...        ...
# 95              -82.94928  2018-12-16T16:00:00.000Z   0.000275
# 96              -88.72517  2024-03-14T07:06:22.000Z   0.657401
# 97              -85.41580  2021-08-20T20:39:48.000Z   0.000395
# 98              -95.77151  2023-01-09T19:14:05.000Z   0.005860
# 99              -24.78136  2024-07-12T00:28:59.000Z   0.962885
#
#     atl_change_percentage                  atl_date  \
# 0            1.132617e+05  2013-07-05T16:00:00.000Z
# 1            5.583024e+05  2015-10-19T16:00:00.000Z
# 2            7.461181e+01  2015-03-01T16:00:00.000Z
# 3            1.774281e+06  2017-10-18T16:00:00.000Z
# 4            5.038666e+04  2014-05-21T16:00:00.000Z
# ..                    ...                       ...
# 95           2.783099e+04  2019-11-01T03:05:12.000Z
# 96           8.024772e+02  2020-11-03T08:19:30.000Z
# 97           7.011147e+03  2019-07-21T16:00:00.000Z
# 98           8.282510e+00  2026-08-19T10:09:30.000Z
# 99           3.561000e+00  2025-04-10T00:30:51.000Z
#
#                                                   roi  \
# 0                                                None
# 1   {'times': 41.039136156189585, 'currency': 'btc...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  {'times': -0.6928350698556385, 'currency': 'us...
# 96                                               None
# 97  {'times': 0.5449029760011064, 'currency': 'eth...
# 98                                               None
# 99                                               None
#
#                 last_updated
# 0   2026-09-10T13:27:20.000Z
# 1   2026-09-10T13:27:20.000Z
# 2   2026-09-10T13:27:20.000Z
# 3   2026-09-10T13:27:20.000Z
# 4   2026-09-10T13:27:20.000Z
# ..                       ...
# 95  2026-09-10T13:27:20.000Z
# 96  2026-09-10T13:27:20.000Z
# 97  2026-09-10T13:27:20.000Z
# 98  2026-09-10T13:27:20.000Z
# 99  2026-09-10T13:27:20.000Z
#
# [100 rows x 26 columns]

# %%
df.to_csv("Scraped_crypto(1).csv")
